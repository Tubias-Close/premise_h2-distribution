# %%
from premise import *
import bw2data, bw2io, bw2calc
bw2data.projects.set_current("research_visit")
#bw2data.projects.set_current("ecoinvent-3.10-cutoff")
#bw2data.projects.set_current("ei-3.11-bw25")
# Out:
# 14:27:33+0200 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# c:\Users\ac145674\AppData\Local\anaconda3\envs\premise-dev\Lib\site-packages\bw2calc\__init__.py:58: UserWarning: No fast sparse solver found
#   warnings.warn("No fast sparse solver found")

# %%
from premise import *
import bw2data, bw2io, bw2calc

# %%
bw2io.ecoinvent.import_ecoinvent_release(
    username='ifuham1028',
    password='SEEdoesLCA2025',
    system_model="cutoff",
    version="3.12"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bw2io.ecoinvent.import_ecoinvent_release(
#       2     username='ifuham1028',
#       3     password='SEEdoesLCA2025',
#       4     system_model="cutoff",
#
# File c:\Users\ac145674\AppData\Local\anaconda3\envs\premise-dev\Lib\site-packages\bw2io\ecoinvent.py:216, in import_ecoinvent_release(version, system_model, username, password, lci, lcia, biosphere_name, biosphere_write_mode, importer_signal, namespace_lcia_methods, use_mp, separate_products)
#     214 db_name = f"ecoinvent-{version}-{system_model}"
#     215 if db_name in bd.databases:
# --> 216     raise ValueError(f"Database {db_name} already exists")
#     218 eb = Ecospold2BiosphereImporter(
#     219     name=biosphere_name,
#     220     filepath=lci_path / "MasterData" / "ElementaryExchanges.xml",
#     221 )
#     222 eb.apply_strategies()
#
# ValueError: Database ecoinvent-3.12-cutoff already exists

# %%
bw2data.databases
# Out:
# Databases dictionary with 4 object(s):
# 	PtX
# 	biosphere-3.12
# 	ecoinvent-3.12-cutoff
# 	h2-test-remind_2030

# %%
clear_inventory_cache()
# Out:
# Inventory cache cleared!

# %%
scenarios = [
    #{"model": "remind", "pathway": "SSP1-NPi", "year": 2050,},
    #{"model": "remind", "pathway": "SSP1-PkBudg650", "year": 2025,},
    #{"model": "remind", "pathway": "SSP1-PkBudg1000", "year": 2025,},
    
    #{"model": "remind", "pathway": "SSP2-NDC", "year": 2025,},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2025,},
    #{"model": "remind", "pathway": "SSP2-PkBudg650", "year": 2050,},
    #{"model": "remind", "pathway": "SSP2-PkBudg1000", "year": 2025,},
    
    #{"model": "remind", "pathway": "SSP3-rollBack", "year": 2025,},

    #{"model": "remind-eu", "pathway": "SSP2-NPi", "year": 2025,},
    #{"model": "remind-eu", "pathway": "SSP2-NDC", "year": 2025,},
    #{"model": "remind-eu", "pathway": "SSP2-PkBudg650", "year": 2050,},
    #{"model": "remind-eu", "pathway": "SSP2-PkBudg1000", "year": 2025,},

    #{"model": "image", "pathway": "SSP1-L", "year": 2050,},
    #{"model": "image", "pathway": "SSP1-Ma", "year": 2025,},
    #{"model": "image", "pathway": "SSP1-VLLO", "year": 2025,},
    #{"model": "image", "pathway": "SSP2-L", "year": 2060,},
    #{"model": "image", "pathway": "SSP2-M", "year": 2050,},
    #{"model": "image", "pathway": "SSP2-VLHO", "year": 2025,},
    #{"model": "image", "pathway": "SSP5-H", "year": 2025,},
    #{"model": "image", "pathway": "SSP3-H", "year": 2025,},

    #{"model": "tiam-ucl", "pathway": "SSP2-RCP19", "year": 2050,},
    #{"model": "tiam-ucl", "pathway": "SSP2-RCP19", "year": 2025,},
    #{"model": "tiam-ucl", "pathway": "SSP2-RCP26", "year": 2025,},
    #{"model": "tiam-ucl", "pathway": "SSP2-RCP45", "year": 2025,},

    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2030,},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2035,},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2040,},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2045,},
    #{"model": "remind", "pathway": "SSP2-NPi", "year": 2050,},

    {"model": "remind", "pathway": "SSP2-NDC", "year": 2030,},
    #{"model": "remind", "pathway": "SSP2-NDC", "year": 2035,},
    #{"model": "remind", "pathway": "SSP2-NDC", "year": 2040,},
    #{"model": "remind", "pathway": "SSP2-NDC", "year": 2045,},
    {"model": "remind", "pathway": "SSP2-NDC", "year": 2050,},

    #{"model": "remind", "pathway": "SSP2-rollBack", "year": 2030,},
    #{"model": "remind", "pathway": "SSP2-rollBack", "year": 2035,},
    #{"model": "remind", "pathway": "SSP2-rollBack", "year": 2040,},
    #{"model": "remind", "pathway": "SSP2-rollBack", "year": 2045,},
    #{"model": "remind", "pathway": "SSP2-rollBack", "year": 2050,},

    #{"model": "gcam", "pathway": "SSP2-Base", "year": 2050,},
    #{"model": "gcam", "pathway": "SSP2-RCP26", "year": 2050,},
    #{"model": "gcam", "pathway": "SSP2-RCP45", "year": 2050,},
    #{"model": "tiam-ucl", "pathway": "SSP2-RCP19", "year": 2050}

    #{"model": "message", "pathway": "SSP1-L", "year": 2050},
    #{"model": "message", "pathway": "SSP1-VL", "year": 2050},
    #{"model": "message", "pathway": "SSP2-L", "year": 2050},
    #{"model": "message", "pathway": "SSP2-LO", "year": 2050},
    #{"model": "message", "pathway": "SSP2-M", "year": 2050},
    #{"model": "message", "pathway": "SSP2-ML", "year": 2050},
    #{"model": "message", "pathway": "SSP2-VL", "year": 2050},
    #{"model": "message", "pathway": "SSP3-H", "year": 2050},
    #{"model": "message", "pathway": "SSP4-LO", "year": 2050},
    #{"model": "message", "pathway": "SSP5-H", "year": 2050},
    #{"model": "message", "pathway": "SSP5-LO", "year": 2050},
    
]


ndb = NewDatabase(
    scenarios=scenarios,
    source_db="ecoinvent-3.12-cutoff",
    source_version="3.12",
    # key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
    biosphere_name="biosphere-3.12",
)
# Out:
# Reading unencrypted IAM output files.
# Reading unencrypted IAM output files.
# premise v.(2, 4, 4)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-Carma-CCS.xlsx
# Extracted 1 worksheets in 0.47 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.5 -> 3.6
# Applying forward migration 3.6 -> 3.7
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-co-firing-power-plants.xlsx
# Extracted 1 worksheets in 0.06 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.5 -> 3.6
# Applying forward migration 3.6 -> 3.7
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-combined-heat-power-plant-CCS.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.5 -> 3.6
# Applying forward migration 3.6 -> 3.7
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-carbon-capture.xlsx
# Extracted 1 worksheets in 0.11 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-biogas.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.6 -> 3.7
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-waste-CHP.xlsx
# Extracted 4 worksheets in 0.82 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-carbon-fiber.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-lithium.xlsx
# Extracted 7 worksheets in 0.13 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-cobalt.xlsx
# Extracted 1 worksheets in 0.11 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-NMC955-LTO.xlsx
# Extracted 1 worksheets in 0.10 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------------------------+
# |              Name              |       Reference product        | Location |              File             |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# | market for battery management  | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# | battery management system prod | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-LiS.xlsx
# Extracted 1 worksheets in 0.14 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-LiO2.xlsx
# Extracted 1 worksheets in 0.09 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-vanadium.xlsx
# Extracted 1 worksheets in 0.15 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------------+
# |              Name              |       Reference product        | Location |             File            |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# | market for styrene butadiene r | styrene butadiene rubber (SBR) |   RER    | lci-batteries-vanadium.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-vanadium-redox-flow.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-organic-and-hybrid-redox-flow.xlsx
# Extracted 1 worksheets in 0.18 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. Flow ignored.
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. Flow ignored.
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-batteries-SIB.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-battery-capacity.xlsx
# Extracted 2 worksheets in 0.08 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-home-batteries.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-heat-pump-high-temp.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.11 → 3.12
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-PV.xlsx
# Extracted 2 worksheets in 6.19 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | 1,1-difluoroethane production  |       1,1-difluoroethane       |    US    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |   multi-Si wafer production    |         multi-Si wafer         |   RER    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, multi-S |   RER    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, single- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, multi-Si w |   RER    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, single-Si  |   RER    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaics, electric instal | photovoltaics, electric instal |    CH    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, multi-Si,  |   silicon, multi-Si, casted    |   RER    | lci-PV.xlsx |
# | silicon production, single cry | silicon, single crystal, Czoch |   RER    | lci-PV.xlsx |
# | silicon production, solar grad |      silicon, solar grade      |   RER    | lci-PV.xlsx |
# | single-Si wafer production, ph | single-Si wafer, photovoltaic  |   RER    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-PGM.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-electrolysis.xlsx
# Extracted 1 worksheets in 1.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-thermochemical-water-splitting.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-pyrolysis.xlsx
# Extracted 1 worksheets in 0.09 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-methanol-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-methanol.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# WARNING: missing classification for liquefied petroleum gas production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, economic allocation, at fuelling station | liquefied petroleum gas, synthetic, vehicle grade
# WARNING: missing classification for kerosene production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, economic allocation, at fuelling station | kerosene, synthetic, vehicle grade
# WARNING: missing classification for diesel production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, economic allocation, at fuelling station | diesel, synthetic, vehicle grade
# WARNING: missing classification for gasoline production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, economic allocation, at fuelling station | gasoline, synthetic, vehicle grade
# WARNING: missing classification for liquefied petroleum gas production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, energy allocation, at fuelling station | liquefied petroleum gas, synthetic, vehicle grade
# WARNING: missing classification for kerosene production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, energy allocation, at fuelling station | kerosene, synthetic, vehicle grade
# WARNING: missing classification for diesel production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, energy allocation, at fuelling station | diesel, synthetic, vehicle grade
# WARNING: missing classification for gasoline production, synthetic, from methanol, market-average hydrogen, CO2 from DAC, energy allocation, at fuelling station | gasoline, synthetic, vehicle grade
# WARNING: missing classification for kerosene production, from methanol, market-average hydrogen, CO2 from DAC, energy allocation | kerosene, synthetic
# WARNING: missing classification for kerosene production, from methanol, market-average hydrogen, CO2 from DAC, economic allocation | kerosene, synthetic
# WARNING: missing classification for diesel production, from methanol, market-average hydrogen, CO2 from DAC, energy allocation | diesel, synthetic
# WARNING: missing classification for diesel production, from methanol, market-average hydrogen, CO2 from DAC, economic allocation | diesel, synthetic
# WARNING: missing classification for gasoline production, from methanol, market-average hydrogen, CO2 from DAC, energy allocation | gasoline, synthetic
# WARNING: missing classification for gasoline production, from methanol, market-average hydrogen, CO2 from DAC, economic allocation | gasoline, synthetic
# WARNING: missing classification for liquefied petroleum gas production, from methanol, market-average hydrogen, CO2 from DAC, energy allocation | liquefied petroleum gas, synthetic
# WARNING: missing classification for liquefied petroleum gas production, from methanol, market-average hydrogen, CO2 from DAC, economic allocation | liquefied petroleum gas, synthetic
# WARNING: missing classification for methanol distillation, market-average hydrogen, CO2 from DAC | methanol, purified
# WARNING: missing classification for methanol synthesis, market-average hydrogen, CO2 from DAC | methanol, unpurified
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-methanol-from-cement-plant.xlsx
# Extracted 1 worksheets in 0.06 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-coal-gasification.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, coal gasi | hydrogen, gaseous, low pressur |   RoW    | lci-hydrogen-coal-gasification |
# | methanol production, from coal |            methanol            |    CN    | lci-hydrogen-coal-gasification |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-coal-gasification_CCS.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-methanol-from-coal.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-methanol-from-coal-with-CCS.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-distribution.xlsx
# Extracted 1 worksheets in 0.09 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-smr-atr-biogas.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-smr-atr-natgas.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, steam met | hydrogen, gaseous, low pressur |   RER    | lci-hydrogen-smr-atr-natgas.xl |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-wood-gasification.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-oil.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-turbine.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-syngas.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-methanol-from-wood.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | methanol production facility,  | methanol production facility,  |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-ammonia.xlsx
# Extracted 1 worksheets in 0.10 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# WARNING: missing classification for ammonia production, with market-average hydrogen | ammonia, anhydrous, liquid
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-syngas-from-coal.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-biofuels.xlsx
# Extracted 5 worksheets in 0.64 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# WARNING: missing classification for kerosene production, synthetic, from Fischer Tropsch process, market-average hydrogen, economic allocation, at fuelling station | kerosene, synthetic
# WARNING: missing classification for diesel production, synthetic, from Fischer Tropsch process, market-average hydrogen, economic allocation, at fuelling station | diesel, synthetic, vehicle grade
# WARNING: missing classification for kerosene production, synthetic, from Fischer Tropsch process, market-average hydrogen, energy allocation, at fuelling station | kerosene, synthetic
# WARNING: missing classification for diesel production, synthetic, from Fischer Tropsch process, market-average hydrogen, energy allocation, at fuelling station | diesel, synthetic, vehicle grade
# WARNING: missing classification for kerosene production, synthetic, Fischer Tropsch process, market-average hydrogen, economic allocation | kerosene, synthetic
# WARNING: missing classification for naphtha production, synthetic, Fischer Tropsch process, market-average hydrogen, economic allocation | naphtha, synthetic
# WARNING: missing classification for diesel production, synthetic, Fischer Tropsch process, market-average hydrogen, economic allocation | diesel, synthetic
# WARNING: missing classification for lubricating oil production, synthetic, Fischer Tropsch process, market-average hydrogen, energy allocation | lubricating oil, synthetic
# WARNING: missing classification for kerosene production, synthetic, Fischer Tropsch process, market-average hydrogen, energy allocation | kerosene, synthetic
# WARNING: missing classification for naphtha production, synthetic, Fischer Tropsch process, market-average hydrogen, energy allocation | naphtha, synthetic
# WARNING: missing classification for diesel production, synthetic, Fischer Tropsch process, market-average hydrogen, energy allocation | diesel, synthetic
# WARNING: missing classification for liquefied petroleum gas production, synthetic, Fischer Tropsch process, market-average hydrogen, energy allocation | liquefied petroleum gas, synthetic
# WARNING: missing classification for syngas, RWGS, Production, for Fischer Tropsch process, market-average hydrogen | syngas, RWGS, Production, for Fischer Tropsch process, market-average hydrogen
# WARNING: missing classification for carbon monoxide, from RWGS, for Fischer Tropsch process, market-average hydrogen | carbon monoxide, from RWGS
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT-from-natural-gas.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT-from-wood-gasification.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT-from-wood-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.06 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT-from-coal-gasification.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-synfuels-from-FT-from-coal-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-transport.xlsx
# Extracted 1 worksheets in 0.03 seconds
# WARNING: missing classification for transport, freight, sea, tanker for liquefied natural gas, ammonia and MDO | transport, freight, sea, tanker for liquefied natural gas
# the following exchanges from lci-hydrogen-transport are missing uncertainty information:
# +--------------------------------+----------------------+------------------+---------------------------+
# |              Name              |       Exchange       | Uncertainty type |       Missing param.      |
# +--------------------------------+----------------------+------------------+---------------------------+
# | transport, freight, sea, tanke | market for bilge oil |        2         | 'negative' should be TRUE |
# +--------------------------------+----------------------+------------------+---------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-geothermal.xlsx
# Extracted 1 worksheets in 0.13 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.6 -> 3.7
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-BIGCC.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-nuclear_EPR.xlsx
# Extracted 1 worksheets in 0.35 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-nuclear_SMR.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-wave_energy.xlsx
# Extracted 1 worksheets in 0.06 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-fuel_cell.xlsx
# Extracted 1 worksheets in 0.10 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-concentrating-solar-power.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-hydrogen-heating.xlsx
# Extracted 1 worksheets in 0.10 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-methanol-heating.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-electric-heating.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-germanium.xlsx
# Extracted 1 worksheets in 1.02 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Could not find a biosphere flow for ('Sodium I', 'natural resource', 'in ground', 'kilogram') in lci-germanium.xlsx. Flow ignored.
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-rhenium.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-two_wheelers.xlsx
# Extracted 19 worksheets in 1.43 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-trucks.xlsx
# Extracted 1 worksheets in 0.59 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-buses.xlsx
# Extracted 1 worksheets in 0.79 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+----------------+
# |              Name              |       Reference product        | Location |      File      |
# +--------------------------------+--------------------------------+----------+----------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-buses.xlsx |
# +--------------------------------+--------------------------------+----------+----------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-pass_cars.xlsx
# Extracted 1 worksheets in 9.06 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +-----------------+-------------------+----------+--------------------+
# |       Name      | Reference product | Location |        File        |
# +-----------------+-------------------+----------+--------------------+
# | HDPE tank liner |  HDPE tank liner  |   RER    | lci-pass_cars.xlsx |
# +-----------------+-------------------+----------+--------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-rail-freight.xlsx
# Extracted 1 worksheets in 0.14 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-PV-GaAs.xlsx
# Extracted 1 worksheets in 0.08 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-PV-perovskite.xlsx
# Extracted 1 worksheets in 0.12 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-biochar-spruce.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-ocean-liming.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-coastal-enhanced-weathering.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-final-energy.xlsx
# Extracted 1 worksheets in 0.93 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------+
# |              Name              |       Reference product        | Location |          File         |
# +--------------------------------+--------------------------------+----------+-----------------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-final-energy.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-sulfidic-tailings.xlsx
# Extracted 3 worksheets in 0.03 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+-------------------+----------+----------------------------+
# |              Name              | Reference product | Location |            File            |
# +--------------------------------+-------------------+----------+----------------------------+
# | carbon disulfide production, f |  carbon disulfide |   GLO    | lci-sulfidic-tailings.xlsx |
# +--------------------------------+-------------------+----------+----------------------------+
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-ships.xlsx
# Extracted 1 worksheets in 0.07 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Importing C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\additional_inventories\lci-steel.xlsx
# Extracted 8 worksheets in 0.33 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying forward migration 3.10 -> 3.11
# Applying forward migration 3.11 -> 3.12
# Data cached. Continuing with the cached inventory representation for
# the rest of this workflow.
# - Fetching IAM data
# Found file: remind_SSP2-NDC
# Reading remind_SSP2-NDC as CSV file
# The following variables are missing from the IAM file: C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\iam_output_files
# +----------------------------------+
# |             Variable             |
# +----------------------------------+
# | Production|Industry|Cement w CCS |
# +----------------------------------+
# The following variables are missing from the IAM file: C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\iam_output_files
# +----------------------------------+
# |             Variable             |
# +----------------------------------+
# | Production|Industry|Cement w CCS |
# +----------------------------------+
# Found file: remind_SSP2-NDC
# Reading remind_SSP2-NDC as CSV file
# The following variables are missing from the IAM file: C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\iam_output_files
# +----------------------------------+
# |             Variable             |
# +----------------------------------+
# | Production|Industry|Cement w CCS |
# +----------------------------------+
# The following variables are missing from the IAM file: C:\Users\ac145674\coding_projects\premise_h2-distribution\premise\data\iam_output_files
# +----------------------------------+
# |             Variable             |
# +----------------------------------+
# | Production|Industry|Cement w CCS |
# +----------------------------------+
# Done!

# %%
ndb.update()
# Out:
# Processing scenarios for all sectors: 100%|█| 2/2 [20:00<00:00, 600.40
# Done!

# %%
# bw2data.projects.set_current("default")
ndb.write_db_to_brightway(
    [
        "ecoinvent-3.12-cutoff_h2-test-remind_2030",
        "ecoinvent-3.12-cutoff_h2-test-remind_2050",
    ]
)
# Out:
# Write new database(s) to Brightway.
# Running core export checks...
# Minor anomalies found: check the change report.
# Brightway database written: ecoinvent-3.12-cutoff_h2-test-remind_2030
# Running core export checks...
# Minor anomalies found: check the change report.
# Brightway database written: ecoinvent-3.12-cutoff_h2-test-remind_2050
# Generate scenario report.
# Report saved under c:\Users\ac145674\coding_projects\premise_h2-distribution\dev\export\scenario_report.
# Generate change report.
# Report saved under c:\Users\ac145674\coding_projects\premise_h2-distribution\dev/export/change reports/.

# %%
db = bw2data.Database("h2-test-remind_2030")

# %%
act = db.random()

# %%
act.as_dict()
# Out:
# {'location': 'ZA',
#  'name': 'petroleum coke production, petroleum refinery operation',
#  'reference product': 'petroleum coke',
#  'unit': 'kilogram',
#  'comment': 'This dataset describes the operation of a typical oil refinery in the given geography. Since refineries are very complex the actual unit process modeling is done in a separate refinery model by ifeu and this is a subdivided product-specific dataset.\nThe ifeu refinery model reproduces the complexity of petroleum refinery plants in which the combination and sequence of processes are usually very specific to the characteristics of the raw materials (i.e. the close relation between the composition of the crude oil and the products to be produced). Refineries differ not only in their configurations, process integration, feedstocks, product mixes, unit sizes, designs, and control systems but also the market situations, locations and ages of the refinery or environmental regulations can result in a wide variety of refinery concepts. It represents the current European state-of-the-art. The basic setting of the model reflects the technical characteristics of European refineries as described in the BREF - BAT reference document for the Refining of Mineral Oil and Gas. Further specific data was collected from companies and production plants and was incorporated in order to elaborate a comprehensive and robust model of a refinery.\nThe BREF contains not only aggregated numbers or weighted averages of emission and energy or water consumptions, but also encompasses primary data of the majority of refineries in Europe in anonymous form. The data quality is excellent. This data source has been complemented by various specific confidential refinery datasets, by values from Eurostat (e.g. in the case of the energy source mix or process energy), and by literature data. In the case of the BREF, a range of values were mentioned as process parameters for which the arithmetic averages were applied. After adapting the model to the up-to-date mass and energy flows within the European refineries, it has been validated and calibrated by comparing the results to the dataset of the BREF, the Eurostat and the European Pollutant Release and Transfer Register (E-PRTR).\nDespite the default settings (weighted EU average), the refinery model was adjusted to fit typical refinery production data in the special geographies. In order to do this data from the refineries in the countries was analysed and an assessment of the refinery complexity (according to the BREF classes) was done. Furthermore crude oil qualities were researched an adjusted (e.g. sulphur content and API class) to fit the specified geography.\nDocumentation for this model can be found in the ecoinvent refinery report by Fehrenbach et al. (2018).\nGeography:  Global model calibrated with country specific information.\nTechnology:  The technology represents a weighted average of BREF types II and III refineries; API 35; sulfur content 0.7%',
#  'classifications': [('ISIC rev.4 ecoinvent',
#    '1920:Manufacture of refined petroleum products'),
#   ('CPC',
#    '33500: Petroleum jelly; paraffin wax, micro- crystalline petroleum wax, slack wax, ozokerite, lignite wax, peat wax, […]')],
#  'code': '24504a16660049f7ad3cbf138974751d',
#  'database': 'h2-test-remind_2030',
#  'type': 'processwithreferenceproduct',
#  'id': 315829796220698624}

# %%
from premise.utils import load_database

db = load_database(ndb.scenarios[0], ndb.database)["database"]
# Out:
# WARNING: loading unmodified database!

# %%
for ds in db:
    if ds["name"].startswith("hardwood forestry, birch, sustainable forest management"):
        for e in ds["exchanges"]:
            print(e["name"], "|", e.get("product"), "|", e["amount"], "|", e["unit"], "|", e.get("location"))
        print()
# Out:
# hardwood forestry, birch, sustainable forest management | sawlog and veneer log, hardwood, with bark, green, measured as green volume under bark | 1.0 | cubic meter | SE
# market for diesel, burned in building machine | diesel, burned in building machine | 7.878255 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.048244856 | hour | RoE
# market for gravel, crushed | gravel, crushed | 8.1872425 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.0979 | hour | RoE
# power sawing, without catalytic converter | power sawing, without catalytic converter | 0.12415918 | hour | RER
# skidding, skidder | skidding, skidder | 0.00134 | hour | RER
# Carbon dioxide, in air | None | 1129.6279 | kilogram | None
# Energy, gross calorific value, in biomass | None | 12223.431 | megajoule | None
# Occupation, forest, intensive | None | 1229.8889 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 4.6790123 | square meter-year | None
# Transformation, from forest, intensive | None | 20.498148 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Transformation, to forest, intensive | None | 20.498148 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Wood, hard, standing | None | 1.0 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | pulpwood, hardwood, with bark, green, measured as green volume under bark | 1.0 | cubic meter | SE
# market for diesel, burned in building machine | diesel, burned in building machine | 7.878255 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.048244856 | hour | RoE
# market for gravel, crushed | gravel, crushed | 8.1872425 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.0979 | hour | RoE
# power sawing, without catalytic converter | power sawing, without catalytic converter | 0.12415918 | hour | RER
# skidding, skidder | skidding, skidder | 0.00134 | hour | RER
# Carbon dioxide, in air | None | 1129.6279 | kilogram | None
# Energy, gross calorific value, in biomass | None | 12223.431 | megajoule | None
# Occupation, forest, intensive | None | 1229.8889 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 4.6790123 | square meter-year | None
# Transformation, from forest, intensive | None | 20.498148 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Transformation, to forest, intensive | None | 20.498148 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Wood, hard, standing | None | 1.0 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | forest chips, green, from logging residues, measured as dry mass | 1.0 | kilogram | FI
# market for diesel, burned in building machine | diesel, burned in building machine | 0.006589812 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.00016246729 | hour | FI
# market for gravel, crushed | gravel, crushed | 0.03981487 | kilogram | RoW
# harvesting/bundling, energy wood harvester | harvesting/bundling, energy wood harvester | 0.00041596574 | hour | FI
# market for transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | 3.191535e-07 | ton kilometer | RER
# tree seedling production | tree seedling, for planting | 0.0006636312 | unit | FI
# wood chipping, mobile chipper, at forest road | wood chipping, chipper, mobile, diesel, at forest road | 4.1606854e-05 | hour | FI
# Carbon dioxide, in air | None | 1.9107443 | kilogram | None
# Energy, gross calorific value, in biomass | None | 20.259235 | megajoule | None
# Occupation, forest, intensive | None | 3.645485 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.014027297 | square meter-year | None
# Transformation, from forest, intensive | None | 0.028134458 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 9.819108e-05 | square meter | None
# Transformation, to forest, intensive | None | 0.028134458 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 9.819108e-05 | square meter | None
# Wood, hard, standing | None | 0.001995777 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | cleft timber, green, measured as dry mass | 1.0 | kilogram | RoW
# market for clefting of energy wood | clefting of energy wood | 0.00047420128 | hour | GLO
# market for diesel, burned in building machine | diesel, burned in building machine | 0.012632607 | megajoule | GLO
# market for forwarding, forwarder | forwarding, forwarder | 7.735955e-05 | hour | GLO
# market for gravel, crushed | gravel, crushed | 0.009923022 | kilogram | RoW
# market for gravel, crushed | gravel, crushed | 0.0025852183 | kilogram | IN
# market for gravel, crushed | gravel, crushed | 5.1698982e-05 | kilogram | CA-QC
# market for gravel, crushed | gravel, crushed | 3.413296e-06 | kilogram | CH
# market for gravel, crushed | gravel, crushed | 0.0005647086 | kilogram | BR
# market for harvesting, forestry harvester | harvesting, forestry harvester | 0.00015698047 | hour | GLO
# market for power sawing, without catalytic converter | power sawing, without catalytic converter | 0.00019908648 | hour | GLO
# market for skidding, skidder | skidding, skidder | 2.1486603e-06 | hour | GLO
# Carbon dioxide, in air | None | 1.8113333 | kilogram | None
# Energy, gross calorific value, in biomass | None | 19.6 | megajoule | None
# Occupation, forest, intensive | None | 1.9720995 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.0075026923 | square meter-year | None
# Transformation, from forest, intensive | None | 0.032868326 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Transformation, to forest, intensive | None | 0.032868326 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Wood, hard, standing | None | 0.0016034778 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | wood chips, green, measured as dry mass | 1.0 | kilogram | RoW
# market for diesel, burned in building machine | diesel, burned in building machine | 0.012632607 | megajoule | GLO
# market for forwarding, forwarder | forwarding, forwarder | 7.627096e-05 | hour | GLO
# market for gravel, crushed | gravel, crushed | 0.009923022 | kilogram | RoW
# market for gravel, crushed | gravel, crushed | 0.0025852183 | kilogram | IN
# market for gravel, crushed | gravel, crushed | 5.1698982e-05 | kilogram | CA-QC
# market for gravel, crushed | gravel, crushed | 3.413296e-06 | kilogram | CH
# market for gravel, crushed | gravel, crushed | 0.0005647086 | kilogram | BR
# market for harvesting, forestry harvester | harvesting, forestry harvester | 0.00015698047 | hour | GLO
# market for power sawing, without catalytic converter | power sawing, without catalytic converter | 0.00019908648 | hour | GLO
# market for skidding, skidder | skidding, skidder | 1.910159e-06 | hour | GLO
# market for wood chipping, chipper, mobile, diesel, at forest road | wood chipping, chipper, mobile, diesel, at forest road | 3.6957194e-05 | hour | GLO
# market for wood chipping, forwarder with terrain chipper, in forest | wood chipping, forwarder with terrain chipper, in forest | 2.2149374e-05 | hour | GLO
# Carbon dioxide, in air | None | 1.8113333 | kilogram | None
# Energy, gross calorific value, in biomass | None | 19.6 | megajoule | None
# Occupation, forest, intensive | None | 1.9720995 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.0075026923 | square meter-year | None
# Transformation, from forest, intensive | None | 0.032868326 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Transformation, to forest, intensive | None | 0.032868326 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Wood, hard, standing | None | 0.0016034778 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | sawlog and veneer log, hardwood, with bark, green, measured as green volume under bark | 1.0 | cubic meter | RoW
# market for diesel, burned in building machine | diesel, burned in building machine | 7.878255 | megajoule | GLO
# market for forwarding, forwarder | forwarding, forwarder | 0.048244856 | hour | GLO
# market for gravel, crushed | gravel, crushed | 6.188438 | kilogram | RoW
# market for gravel, crushed | gravel, crushed | 1.612257 | kilogram | IN
# market for gravel, crushed | gravel, crushed | 0.03224178 | kilogram | CA-QC
# market for gravel, crushed | gravel, crushed | 0.002128683 | kilogram | CH
# market for gravel, crushed | gravel, crushed | 0.3521774 | kilogram | BR
# market for harvesting, forestry harvester | harvesting, forestry harvester | 0.0979 | hour | GLO
# market for power sawing, without catalytic converter | power sawing, without catalytic converter | 0.12415918 | hour | GLO
# market for skidding, skidder | skidding, skidder | 0.00134 | hour | GLO
# Carbon dioxide, in air | None | 1129.6279 | kilogram | None
# Energy, gross calorific value, in biomass | None | 12223.431 | megajoule | None
# Occupation, forest, intensive | None | 1229.8889 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 4.6790123 | square meter-year | None
# Transformation, from forest, intensive | None | 20.498148 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Transformation, to forest, intensive | None | 20.498148 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Wood, hard, standing | None | 1.0 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | cleft timber, green, measured as dry mass | 1.0 | kilogram | SE
# clefting/splitting of energy wood | clefting of energy wood | 0.00047420128 | hour | RER
# market for diesel, burned in building machine | diesel, burned in building machine | 0.012632607 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 7.735955e-05 | hour | RoE
# market for gravel, crushed | gravel, crushed | 0.013128062 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.00015698047 | hour | RoE
# power sawing, without catalytic converter | power sawing, without catalytic converter | 0.00019908648 | hour | RER
# skidding, skidder | skidding, skidder | 2.1486603e-06 | hour | RER
# Carbon dioxide, in air | None | 1.8113333 | kilogram | None
# Energy, gross calorific value, in biomass | None | 19.6 | megajoule | None
# Occupation, forest, intensive | None | 1.9720995 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.0075026923 | square meter-year | None
# Transformation, from forest, intensive | None | 0.032868326 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Transformation, to forest, intensive | None | 0.032868326 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Wood, hard, standing | None | 0.0016034778 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | fuel wood, green, measured as dry mass | 1.0 | kilogram | FI
# market for diesel, burned in building machine | diesel, burned in building machine | 0.006589812 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.00016246729 | hour | FI
# market for gravel, crushed | gravel, crushed | 0.03981487 | kilogram | RoW
# harvesting/bundling, energy wood harvester | harvesting/bundling, energy wood harvester | 0.00041596574 | hour | FI
# market for transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | 9.532492e-07 | ton kilometer | RER
# tree seedling production | tree seedling, for planting | 0.0006636312 | unit | FI
# Carbon dioxide, in air | None | 1.9107443 | kilogram | None
# Energy, gross calorific value, in biomass | None | 20.259235 | megajoule | None
# Occupation, forest, intensive | None | 3.645485 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.014027297 | square meter-year | None
# Transformation, from forest, intensive | None | 0.028134458 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 9.819108e-05 | square meter | None
# Transformation, to forest, intensive | None | 0.028134458 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 9.819108e-05 | square meter | None
# Wood, hard, standing | None | 0.001995777 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | pulpwood, hardwood, with bark, green, measured as green volume over bark | 1.0 | cubic meter | FI
# market for diesel, burned in building machine | diesel, burned in building machine | 3.4062738 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.083979346 | hour | FI
# market for gravel, crushed | gravel, crushed | 20.580307 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.058952097 | hour | FI
# market for transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | 0.0014474234 | ton kilometer | RER
# tree seedling production | tree seedling, for planting | 0.34303096 | unit | FI
# Carbon dioxide, in air | None | 987.66376 | kilogram | None
# Energy, gross calorific value, in biomass | None | 10471.999 | megajoule | None
# Occupation, forest, intensive | None | 1884.3512 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 7.2507095 | square meter-year | None
# Transformation, from forest, intensive | None | 14.542702 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.050754968 | square meter | None
# Transformation, to forest, intensive | None | 14.542702 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.050754968 | square meter | None
# Wood, hard, standing | None | 1.0316172 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | bundle, energy wood, green, measured as dry mass | 1.0 | kilogram | RoW
# market for diesel, burned in building machine | diesel, burned in building machine | 0.012632607 | megajoule | GLO
# market for forwarding, forwarder | forwarding, forwarder | 3.450554e-05 | hour | GLO
# market for gravel, crushed | gravel, crushed | 0.009923022 | kilogram | RoW
# market for gravel, crushed | gravel, crushed | 0.0025852183 | kilogram | IN
# market for gravel, crushed | gravel, crushed | 5.1698982e-05 | kilogram | CA-QC
# market for gravel, crushed | gravel, crushed | 3.413296e-06 | kilogram | CH
# market for gravel, crushed | gravel, crushed | 0.0005647086 | kilogram | BR
# market for harvesting, forestry harvester | harvesting, forestry harvester | 0.00015698047 | hour | GLO
# market for harvesting/bundling, energy wood harvester | harvesting/bundling, energy wood harvester | 0.00021465565 | hour | GLO
# market for power sawing, without catalytic converter | power sawing, without catalytic converter | 0.00019908648 | hour | GLO
# Carbon dioxide, in air | None | 1.8113333 | kilogram | None
# Energy, gross calorific value, in biomass | None | 19.6 | megajoule | None
# Occupation, forest, intensive | None | 1.9720995 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.0075026923 | square meter-year | None
# Transformation, from forest, intensive | None | 0.032868326 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Transformation, to forest, intensive | None | 0.032868326 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Wood, hard, standing | None | 0.0016034778 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | bundle, energy wood, green, measured as dry mass | 1.0 | kilogram | SE
# market for diesel, burned in building machine | diesel, burned in building machine | 0.012632607 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 3.450554e-05 | hour | RoE
# market for gravel, crushed | gravel, crushed | 0.013128062 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.00015698047 | hour | RoE
# harvesting/bundling, energy wood harvester | harvesting/bundling, energy wood harvester | 0.00021465565 | hour | RoE
# power sawing, without catalytic converter | power sawing, without catalytic converter | 0.00019908648 | hour | RER
# Carbon dioxide, in air | None | 1.8113333 | kilogram | None
# Energy, gross calorific value, in biomass | None | 19.6 | megajoule | None
# Occupation, forest, intensive | None | 1.9720995 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.0075026923 | square meter-year | None
# Transformation, from forest, intensive | None | 0.032868326 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Transformation, to forest, intensive | None | 0.032868326 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Wood, hard, standing | None | 0.0016034778 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | pulpwood, hardwood, with bark, green, measured as green volume under bark | 1.0 | cubic meter | RoW
# market for diesel, burned in building machine | diesel, burned in building machine | 7.878255 | megajoule | GLO
# market for forwarding, forwarder | forwarding, forwarder | 0.048244856 | hour | GLO
# market for gravel, crushed | gravel, crushed | 6.188438 | kilogram | RoW
# market for gravel, crushed | gravel, crushed | 1.612257 | kilogram | IN
# market for gravel, crushed | gravel, crushed | 0.03224178 | kilogram | CA-QC
# market for gravel, crushed | gravel, crushed | 0.002128683 | kilogram | CH
# market for gravel, crushed | gravel, crushed | 0.3521774 | kilogram | BR
# market for harvesting, forestry harvester | harvesting, forestry harvester | 0.0979 | hour | GLO
# market for power sawing, without catalytic converter | power sawing, without catalytic converter | 0.12415918 | hour | GLO
# market for skidding, skidder | skidding, skidder | 0.00134 | hour | GLO
# Carbon dioxide, in air | None | 1129.6279 | kilogram | None
# Energy, gross calorific value, in biomass | None | 12223.431 | megajoule | None
# Occupation, forest, intensive | None | 1229.8889 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 4.6790123 | square meter-year | None
# Transformation, from forest, intensive | None | 20.498148 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Transformation, to forest, intensive | None | 20.498148 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.077983536 | square meter | None
# Wood, hard, standing | None | 1.0 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | energy wood, green, from young stand, measured as dry mass | 1.0 | kilogram | FI
# market for diesel, burned in building machine | diesel, burned in building machine | 0.006589812 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.00016246729 | hour | FI
# market for gravel, crushed | gravel, crushed | 0.03981487 | kilogram | RoW
# harvesting/bundling, energy wood harvester | harvesting/bundling, energy wood harvester | 0.00041596574 | hour | FI
# market for transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | 4.893851e-07 | ton kilometer | RER
# tree seedling production | tree seedling, for planting | 0.0006636312 | unit | FI
# Carbon dioxide, in air | None | 1.9107443 | kilogram | None
# Energy, gross calorific value, in biomass | None | 20.259235 | megajoule | None
# Occupation, forest, intensive | None | 3.645485 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.014027297 | square meter-year | None
# Transformation, from forest, intensive | None | 0.028134458 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 9.819108e-05 | square meter | None
# Transformation, to forest, intensive | None | 0.028134458 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 9.819108e-05 | square meter | None
# Wood, hard, standing | None | 0.001995777 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | wood chips, green, measured as dry mass | 1.0 | kilogram | SE
# market for diesel, burned in building machine | diesel, burned in building machine | 0.012632607 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 7.627096e-05 | hour | RoE
# market for gravel, crushed | gravel, crushed | 0.013128062 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.00015698047 | hour | RoE
# power sawing, without catalytic converter | power sawing, without catalytic converter | 0.00019908648 | hour | RER
# skidding, skidder | skidding, skidder | 1.910159e-06 | hour | RER
# wood chipping, mobile chipper, at forest road | wood chipping, chipper, mobile, diesel, at forest road | 3.6957194e-05 | hour | RoE
# wood chipping, terrain chipper, diesel | wood chipping, forwarder with terrain chipper, in forest | 2.2149374e-05 | hour | RER
# Carbon dioxide, in air | None | 1.8113333 | kilogram | None
# Energy, gross calorific value, in biomass | None | 19.6 | megajoule | None
# Occupation, forest, intensive | None | 1.9720995 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 0.0075026923 | square meter-year | None
# Transformation, from forest, intensive | None | 0.032868326 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Transformation, to forest, intensive | None | 0.032868326 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.00012504487 | square meter | None
# Wood, hard, standing | None | 0.0016034778 | cubic meter | None
#
# hardwood forestry, birch, sustainable forest management | sawlog and veneer log, hardwood, with bark, green, measured as green volume over bark | 1.0 | cubic meter | FI
# market for diesel, burned in building machine | diesel, burned in building machine | 3.3986957 | megajoule | GLO
# forwarding, forwarder | forwarding, forwarder | 0.08379251 | hour | FI
# market for gravel, crushed | gravel, crushed | 20.534521 | kilogram | RoW
# harvesting, forestry harvester | harvesting, forestry harvester | 0.05882094 | hour | FI
# market for transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | transport, freight, lorry, 16-32 metric ton, diesel, EURO 5 | 0.00017309116 | ton kilometer | RER
# tree seedling production | tree seedling, for planting | 0.3422678 | unit | FI
# Carbon dioxide, in air | None | 985.46643 | kilogram | None
# Energy, gross calorific value, in biomass | None | 10448.701 | megajoule | None
# Occupation, forest, intensive | None | 1880.1588 | square meter-year | None
# Occupation, traffic area, rail/road embankment | None | 7.234578 | square meter-year | None
# Transformation, from forest, intensive | None | 14.510346 | square meter | None
# Transformation, from traffic area, rail/road embankment | None | 0.050642047 | square meter | None
# Transformation, to forest, intensive | None | 14.510346 | square meter | None
# Transformation, to traffic area, rail/road embankment | None | 0.050642047 | square meter | None
# Wood, hard, standing | None | 1.029322 | cubic meter | None

# %%
len(db)
# Out:
# 29384
